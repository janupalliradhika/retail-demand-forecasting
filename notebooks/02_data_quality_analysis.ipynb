# %% [markdown]
# # M5 Dataset Data Quality Analysis
#
# This notebook performs data quality checks on the M5 retail demand forecasting dataset, including dataset dimensions, data types, missing values, and duplicate records.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load Calendar Dataset

# %%
calendar = pd.read_csv("../data/calendar.csv")

# %% [markdown]
# ### Preview of Calendar Data

# %%
calendar.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %% [markdown]
# ## 3. Calendar Data Quality Checks
#
# The following checks examine the dimensions, data types, missing values, and duplicate records in the calendar dataset.

# %%
calendar.shape
# Out:
# (1969, 14)

# %%
calendar.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1969 non-null   str
#  1   wm_yr_wk      1969 non-null   int64
#  2   weekday       1969 non-null   str
#  3   wday          1969 non-null   int64
#  4   month         1969 non-null   int64
#  5   year          1969 non-null   int64
#  6   d             1969 non-null   str
#  7   event_name_1  162 non-null    str
#  8   event_type_1  162 non-null    str
#  9   event_name_2  5 non-null      str
#  10  event_type_2  5 non-null      str
#  11  snap_CA       1969 non-null   int64
#  12  snap_TX       1969 non-null   int64
#  13  snap_WI       1969 non-null   int64
# dtypes: int64(7), str(7)
# memory usage: 215.5 KB

# %%
calendar.isnull().sum()
# Out:
# date               0
# wm_yr_wk           0
# weekday            0
# wday               0
# month              0
# year               0
# d                  0
# event_name_1    1807
# event_type_1    1807
# event_name_2    1964
# event_type_2    1964
# snap_CA            0
# snap_TX            0
# snap_WI            0
# dtype: int64

# %%
calendar.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 4. Load Sales Dataset
#
# The sales training validation dataset contains product, department, category, store, state, and daily sales information.

# %%
sales = pd.read_csv("../data/sales_train_validation.csv")

# %% [markdown]
# ### Preview of Sales Data

# %%
sales.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# ...

# %% [markdown]
# ## 5. Sales Data Quality Checks
#
# The following checks examine the dimensions, data types, missing values, and duplicate records in the sales dataset.

# %%
sales.shape
# Out:
# (30490, 1919)

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30490 entries, 0 to 30489
# Columns: 1919 entries, id to d_1913
# dtypes: int64(1913), str(6)
# memory usage: 446.4 MB

# %%
sales.isnull().sum()
# Out:
# id          0
# item_id     0
# dept_id     0
# cat_id      0
# store_id    0
#            ..
# d_1909      0
# d_1910      0
# d_1911      0
# d_1912      0
# d_1913      0
# Length: 1919, dtype: int64

# %%
sales.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 6. Unique Values in Sales Data
#
# The following checks identify the number of unique items, departments, categories, stores, and states in the sales dataset.

# %%
sales["item_id"].nunique()
# Out:
# 3049

# %%
sales["dept_id"].nunique()
# Out:
# 7

# %%
sales["cat_id"].nunique()
# Out:
# 3

# %%
sales["store_id"].nunique()
# Out:
# 10

# %%
sales["state_id"].nunique()
# Out:
# 3

# %% [markdown]
# ## 7. Load Price Dataset
#
# The sell prices dataset contains weekly selling prices for items across different stores.

# %%
prices = pd.read_csv("../data/sell_prices.csv")

# %% [markdown]
# ### Preview of Price Data

# %%
prices.head()
# Out:
#   store_id        item_id  wm_yr_wk  sell_price
# 0     CA_1  HOBBIES_1_001     11325        9.58
# 1     CA_1  HOBBIES_1_001     11326        9.58
# 2     CA_1  HOBBIES_1_001     11327        8.26
# 3     CA_1  HOBBIES_1_001     11328        8.26
# 4     CA_1  HOBBIES_1_001     11329        8.26

# %% [markdown]
# ## 8. Price Data Quality Checks
#
# The following checks examine the dimensions, data types, missing values, and duplicate records in the price dataset.

# %%
prices.shape
# Out:
# (6841121, 4)

# %%
prices.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6841121 entries, 0 to 6841120
# Data columns (total 4 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   store_id    str
#  1   item_id     str
#  2   wm_yr_wk    int64
#  3   sell_price  float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 208.8 MB

# %%
prices.isnull().sum()
# Out:
# store_id      0
# item_id       0
# wm_yr_wk      0
# sell_price    0
# dtype: int64

# %%
prices.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 9. Price Statistics

# %%
prices["sell_price"].describe()
# Out:
# count    6.841121e+06
# mean     4.410952e+00
# std      3.408814e+00
# min      1.000000e-02
# 25%      2.180000e+00
# 50%      3.470000e+00
# 75%      5.840000e+00
# max      1.073200e+02
# Name: sell_price, dtype: float64

# %% [markdown]
# ### Unique Stores and Items

# %%
prices["store_id"].nunique()
# Out:
# 10

# %%
prices["item_id"].nunique()
# Out:
# 3049

# %% [markdown]
# ## 10. Data Dictionary

# %% [markdown]
# | File | Column | Meaning |
# |---|---|---|
# | calendar.csv | date | Calendar date |
# | calendar.csv | wm_yr_wk | Walmart year-week identifier |
# | calendar.csv | weekday | Day of the week |
# | calendar.csv | event_name_1 | Event or holiday name |
# | sales_train_validation.csv | item_id | Product identifier |
# | sales_train_validation.csv | dept_id | Department identifier |
# | sales_train_validation.csv | cat_id | Product category |
# | sales_train_validation.csv | store_id | Store identifier |
# | sales_train_validation.csv | state_id | Store state |
# | sell_prices.csv | store_id | Store identifier |
# | sell_prices.csv | item_id | Product identifier |
# | sell_prices.csv | sell_price | Selling price |
